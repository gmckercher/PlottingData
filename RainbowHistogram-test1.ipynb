# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as m
# %matplotlib inline

# %%
f = np.genfromtxt('playground_air.txt', usecols=(0,1))
e = np.genfromtxt('playground_sum.txt', usecols=(0,1))

freq1 = f[:,1]
temp1 = f[:,0]
freq2 = e[:,1]
temp2 = e[:,0]

# %%
fig = plt.gcf()
fig = plt.figure(figsize=[15,10])
ax1 = fig.add_subplot(212)
ax1.set_xlim([30,65])
ax1.set_xlabel('Temperature ($^\circ$C)',fontsize=18)
ax1.set_ylabel('Frequency',fontsize=18)
ax2 = fig.add_subplot(211,sharex=ax1)
#ax2.set_xlim([30,65])

ax2.set_xlabel('Temperature ($^\circ$C)',fontsize=18)
ax2.set_ylabel('Frequency',fontsize=18)



def rainbow_fill(X,Y, cmap='jet'):
    plt.plot(X,Y,lw=0)  # Plot so the axes scale correctly

    dx = X[1]-X[0]
    N  = float(X.size)

    for n, (x,y) in enumerate(zip(X,Y)):
        color = cmap(n/N)
        rect(x,0,dx,y,color)
    
#array = []
#for st in e
 #   if st<np.arrange()
    
ax1.fill_between(temp1,freq1,color='r')
ax2.fill_between(temp2,freq2,color='b')
    
plt.show()

# %%
fig = plt.gcf()
plt.figure(figsize=[15,8])
#plt.title('Power Ranch Temperature Frequency',fontsize=20)
plt.xlabel('Temperature ($^\circ$C)',fontsize=18)
plt.xlim([15,72])
plt.xticks(fontsize=15)
plt.ylabel('Frequency',fontsize=18)
plt.yticks(fontsize=15)
plt.minorticks_on()

def rect(x,y,w,h,c):
    ax = plt.gca()
    polygon = plt.Rectangle((x,y),w,h,color=c)
    ax.add_patch(polygon)

    
cdict = {

  'blue' :  ( (0, 1, 1), 
             #(0, 0, 0), 
             #(0.5, 0.25, 0.25), 
             #(0.75, 0.1, 0.1),
             (1, 0.25, 0.25)),

  'green':  ( (0, 1, 1), 
             #(0.25, 0, 0), 
             #(0.5, 0, 0), 
             #(0.75, 0, 0), 
             (1, 0.5, 0.5)),

  'red'  :  ( (0, 1, 1), 
             #(0.25, 0.25, 0.25), 
             (0.5, 0.5, 0.5), 
             (0.75, 0.9, 0.9), 
             (1, 1, 1))
}

cm = m.colors.LinearSegmentedColormap('my_colormap', cdict, 2000)
    
    
def rainbow_fill(X,Y, cmap=cm):
    plt.plot(X,Y,lw=0)  # Plot so the axes scale correctly

    dx = X[1]-X[0]
    N  = float(X.size)

    for n, (x,y) in enumerate(zip(X,Y)):
        color = cmap(n/N)
        rect(x,0,dx,y,color)
        
# Test data    
X = temp
Y = freq
rainbow_fill(X,Y)
plt.show()

# %%
fig = plt.gcf()
plt.figure(figsize=[15,8])
#plt.title('Power Ranch Temperature Frequency',fontsize=20)
plt.xlabel('Temperature ($^\circ$C)',fontsize=18)
plt.xlim([15,72])
plt.ylim([np.min(freq),np.max(freq)])
plt.xticks(fontsize=15)
plt.ylabel('Frequency',fontsize=18)
plt.yticks(fontsize=15)
plt.minorticks_on()

# calculate polynomial
z = np.polyfit(temp, freq, 10)
f = np.poly1d(z)

# calculate new x's and y's
x_new = np.linspace(np.min(temp), np.max(temp), 500)
y_new = f(x_new)

#np.polyfit(temp,freq)
#plt.plot(temp,freq,'o',x_new,y_new)


plt.fill_between(temp,freq,color='blue')
plt.show()
